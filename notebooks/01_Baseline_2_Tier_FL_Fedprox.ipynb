# %%
# Cell 1: Cấu hình mô phỏng ⚙️
import torch

class SimulationConfig:
    # === 1. Cấu hình thuật toán và mô phỏng ===
    ALGORITHM = 'fedprox' # 'fedavg', 'fedprox'
    NUM_ROUNDS = 200
    
    # === 2. Cấu hình huấn luyện tại Client ===
    LOCAL_EPOCHS = 5
    BATCH_SIZE = 32
    LEARNING_RATE = 0.01

    # === 3. Tham số riêng cho thuật toán ===
    FEDPROX_MU = 0.01

    # === 4. Cấu hình hệ thống và đường dẫn ===
    CONFIG_PATH = '../configs/config.yaml'
    DATA_PATH = '../data'
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    SEED = 42

config = SimulationConfig()

# %%
# Cell 2: Tải cấu hình và chuẩn bị dữ liệu 📦
import yaml, torch, numpy as np, time, copy, os
import matplotlib.pyplot as plt
from torch import nn
import sys
sys.path.append(os.path.abspath(os.path.join('..')))
from src.dataset_preparation import prepare_data
from src.monitoring_utils import ResourceMonitor, shutdown_pynvml
# Thiết lập seed
torch.manual_seed(config.SEED); np.random.seed(config.SEED)

# Đọc file config
print(f"Đang đọc file cấu hình từ: {config.CONFIG_PATH}")
with open(config.CONFIG_PATH, 'r') as f:
    loaded_config = yaml.safe_load(f)
data_params = loaded_config['data_config']
print(f"Đã tải cấu hình dữ liệu: {data_params}")

# Chuẩn bị dữ liệu dựa trên config đã đọc
client_loaders, test_loader, class_names = prepare_data(
    data_path=config.DATA_PATH,
    batch_size=config.BATCH_SIZE,
    seed=config.SEED,
    **data_params  # Sử dụng các tham số từ file yaml, bao gồm cả 'num_clients'
)

# SUY RA SỐ CLIENT TỪ DỮ LIỆU
num_clients = len(client_loaders)
print(f"\nĐã khởi tạo dữ liệu cho {num_clients} client.")
print(f"Sử dụng thiết bị: {config.DEVICE}")
# Out:
# Đang đọc file cấu hình từ: ../configs/config.yaml
# Đã tải cấu hình dữ liệu: {'dataset_name': 'cifar10', 'distribution_mode': 'iid', 'num_clients': 50, 'shards_per_client': 2, 'dirichlet_alpha': 0.5}
#
# Đã khởi tạo dữ liệu cho 50 client.
# Sử dụng thiết bị: cuda

# %%
# Cell 3: Định nghĩa mô hình Neural Network 🧠
class SimpleCNN(nn.Module):
    def __init__(self, num_classes=10, input_size=32):
        super(SimpleCNN, self).__init__()
        self.conv_stack = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2, 2), # 32 -> 16
            nn.Conv2d(32, 64, kernel_size=3, padding=1), nn.ReLU(),
            nn.MaxPool2d(2, 2)  # 16 -> 8
        )
        # Kích thước sau lớp conv cuối cùng: 64 channels * (input_size/4) * (input_size/4)
        feature_size = (input_size // 4) ** 2 * 64
        self.fc_stack = nn.Sequential(
            nn.Flatten(),
            nn.Linear(feature_size, 512), nn.ReLU(),
            nn.Linear(512, num_classes)
        )
    def forward(self, x): return self.fc_stack(self.conv_stack(x))

# %%
# Cell 4: Logic cốt lõi của Federated Learning 🤖
def client_update(client_loader, model):
    # Khởi tạo trình theo dõi
    monitor = ResourceMonitor()
    monitor.start()
    
    start_time = time.time()
    local_model = copy.deepcopy(model).to(config.DEVICE)
    local_model.train()
    optimizer = torch.optim.SGD(local_model.parameters(), lr=config.LEARNING_RATE, momentum=0.9)
    criterion = nn.CrossEntropyLoss()

    for _ in range(config.LOCAL_EPOCHS):
        for data, target in client_loader:
            data, target = data.to(config.DEVICE), target.to(config.DEVICE)
            optimizer.zero_grad()
            output = local_model(data)
            loss = criterion(output, target)
            
            if config.ALGORITHM == 'fedprox':
                proximal_term = sum((local_w - global_w).norm(2)**2 for local_w, global_w in zip(local_model.parameters(), model.parameters()))
                loss += (config.FEDPROX_MU / 2) * proximal_term
                
            loss.backward()
            optimizer.step()
            
            # Cập nhật mức sử dụng đỉnh sau mỗi batch
            monitor.track()

    comp_cost = time.time() - start_time
    
    # Dừng theo dõi và lấy kết quả
    resource_usage = monitor.stop()
    
    # Trả về cả trọng số, thời gian, và tài nguyên sử dụng
    return local_model.state_dict(), comp_cost, resource_usage
def server_aggregate(client_weights_list):
    start_time = time.time(); global_weights = copy.deepcopy(client_weights_list[0]);
    for key in global_weights.keys():
        for i in range(1, len(client_weights_list)): global_weights[key] += client_weights_list[i][key]
        global_weights[key] = torch.div(global_weights[key], len(client_weights_list))
    return global_weights, time.time() - start_time
def calculate_model_size_mb(model): return sum(p.nelement() * p.element_size() for p in model.parameters()) / (1024**2)
def evaluate_model(model, test_loader):
    model.eval(); test_loss, correct = 0, 0; criterion = nn.CrossEntropyLoss(reduction='sum');
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(config.DEVICE), target.to(config.DEVICE)
            output = model(data); test_loss += criterion(output, target).item(); correct += output.argmax(dim=1).eq(target).sum().item()
    return test_loss / len(test_loader.dataset), 100. * correct / len(test_loader.dataset)

# %%
# Cell 5: Vòng lặp huấn luyện chính 🚀

# --- Khởi tạo mô hình và các biến theo dõi ---
input_size = 64 if data_params['dataset_name'] == 'tiny_imagenet' else 32
global_model = SimpleCNN(num_classes=len(class_names), input_size=input_size).to(config.DEVICE)
model_size_mb = calculate_model_size_mb(global_model)
print(f"Kích thước mô hình: {model_size_mb:.4f} MB")

history = {'rounds': [], 'accuracy': [], 'loss': [], 'comm_cost': [], 'comp_cost': [], 'ram_usage': [], 'gpu_usage': []}
print(f"\n--- BẮT ĐẦU MÔ PHỎNG: {config.ALGORITHM.upper()} ---")

for round_idx in range(config.NUM_ROUNDS):
    round_start_time = time.time()
    client_weights_list = []
    
    # Biến để tổng hợp tài nguyên sử dụng trong vòng
    total_client_comp_cost = 0.0
    peak_ram_in_round = 0.0
    peak_gpu_in_round = 0.0
    
    for i in range(num_clients):
        # Nhận thêm kết quả 'resources'
        weights, client_comp_cost, resources = client_update(client_loaders[i], global_model)
        client_weights_list.append(weights)
        total_client_comp_cost += client_comp_cost
        
        # Chúng ta quan tâm đến client có mức sử dụng đỉnh cao nhất trong vòng
        peak_ram_in_round = max(peak_ram_in_round, resources['ram_peak_mb'])
        peak_gpu_in_round = max(peak_gpu_in_round, resources['gpu_peak_mb'])

    global_weights, server_comp_cost = server_aggregate(client_weights_list)
    global_model.load_state_dict(global_weights)
    test_loss, test_accuracy = evaluate_model(global_model, test_loader)
    
    round_comp_cost = total_client_comp_cost + server_comp_cost
    round_comm_cost = 2 * num_clients * model_size_mb
    round_elapsed_time = time.time() - round_start_time
    
    # Ghi lại lịch sử
    history['rounds'].append(round_idx + 1)
    history['accuracy'].append(test_accuracy)
    history['loss'].append(test_loss)
    history['comm_cost'].append(round_comm_cost)
    history['comp_cost'].append(round_comp_cost)
    history['ram_usage'].append(peak_ram_in_round)
    history['gpu_usage'].append(peak_gpu_in_round)
    
    # In log chi tiết
    print(f"--- Vòng {round_idx + 1:02d}/{config.NUM_ROUNDS} ---")
    print(f"  Performance | Accuracy: {test_accuracy:.2f}% | Loss: {test_loss:.4f}")
    print(f"  Costs       | Computation: {round_comp_cost:.2f}s | Communication: {round_comm_cost:.2f}MB")
    print(f"  Resources   | Peak RAM Usage (Client): {peak_ram_in_round:.2f}MB | Peak GPU Mem (Client): {peak_gpu_in_round:.2f}MB")
    print(f"  Round Time  | Total elapsed: {round_elapsed_time:.2f}s")

print("\n--- MÔ PHỎNG HOÀN TẤT ---")
shutdown_pynvml() # Đừng quên đóng kết nối
# Out:
# Kích thước mô hình: 8.0955 MB
#
# --- BẮT ĐẦU MÔ PHỎNG: FEDPROX ---
# --- Vòng 01/200 ---
#   Performance | Accuracy: 47.04% | Loss: 1.5282
#   Costs       | Computation: 53.46s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.12MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 54.76s
# --- Vòng 02/200 ---
#   Performance | Accuracy: 54.07% | Loss: 1.3072
#   Costs       | Computation: 52.46s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 53.72s
# --- Vòng 03/200 ---
#   Performance | Accuracy: 57.42% | Loss: 1.3093
#   Costs       | Computation: 52.13s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 53.38s
# --- Vòng 04/200 ---
#   Performance | Accuracy: 59.72% | Loss: 1.2818
#   Costs       | Computation: 52.31s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 53.58s
# --- Vòng 05/200 ---
#   Performance | Accuracy: 61.00% | Loss: 1.2600
#   Costs       | Computation: 52.59s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 53.87s
# --- Vòng 06/200 ---
#   Performance | Accuracy: 62.40% | Loss: 1.2014
#   Costs       | Computation: 47.31s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 48.50s
# --- Vòng 07/200 ---
#   Performance | Accuracy: 63.87% | Loss: 1.1560
#   Costs       | Computation: 45.44s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 46.58s
# --- Vòng 08/200 ---
#   Performance | Accuracy: 64.52% | Loss: 1.1307
#   Costs       | Computation: 45.53s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 46.70s
# --- Vòng 09/200 ---
#   Performance | Accuracy: 65.10% | Loss: 1.1113
#   Costs       | Computation: 45.52s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 46.69s
# --- Vòng 10/200 ---
#   Performance | Accuracy: 65.52% | Loss: 1.0971
#   Costs       | Computation: 45.54s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 46.68s
# --- Vòng 11/200 ---
#   Performance | Accuracy: 66.25% | Loss: 1.0824
#   Costs       | Computation: 45.63s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 46.80s
# --- Vòng 12/200 ---
#   Performance | Accuracy: 66.73% | Loss: 1.0652
#   Costs       | Computation: 44.79s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.89s
# --- Vòng 13/200 ---
#   Performance | Accuracy: 66.78% | Loss: 1.0672
#   Costs       | Computation: 43.46s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.56s
# --- Vòng 14/200 ---
#   Performance | Accuracy: 67.32% | Loss: 1.0590
#   Costs       | Computation: 43.81s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.90s
# --- Vòng 15/200 ---
#   Performance | Accuracy: 67.38% | Loss: 1.0635
#   Costs       | Computation: 43.73s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.82s
# --- Vòng 16/200 ---
#   Performance | Accuracy: 67.87% | Loss: 1.0536
#   Costs       | Computation: 43.95s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.11s
# --- Vòng 17/200 ---
#   Performance | Accuracy: 67.91% | Loss: 1.0529
#   Costs       | Computation: 43.73s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.83s
# --- Vòng 18/200 ---
#   Performance | Accuracy: 68.24% | Loss: 1.0606
#   Costs       | Computation: 43.88s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.99s
# --- Vòng 19/200 ---
#   Performance | Accuracy: 68.59% | Loss: 1.0605
#   Costs       | Computation: 43.69s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.79s
# --- Vòng 20/200 ---
#   Performance | Accuracy: 68.77% | Loss: 1.0668
#   Costs       | Computation: 43.92s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.01s
# --- Vòng 21/200 ---
#   Performance | Accuracy: 68.72% | Loss: 1.0690
#   Costs       | Computation: 43.94s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.07s
# --- Vòng 22/200 ---
#   Performance | Accuracy: 68.87% | Loss: 1.0728
#   Costs       | Computation: 43.85s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.96s
# --- Vòng 23/200 ---
#   Performance | Accuracy: 69.11% | Loss: 1.0820
#   Costs       | Computation: 43.88s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.98s
# --- Vòng 24/200 ---
#   Performance | Accuracy: 69.08% | Loss: 1.0873
#   Costs       | Computation: 43.78s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.90s
# --- Vòng 25/200 ---
#   Performance | Accuracy: 69.01% | Loss: 1.1018
#   Costs       | Computation: 43.68s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.77s
# --- Vòng 26/200 ---
#   Performance | Accuracy: 69.17% | Loss: 1.1060
#   Costs       | Computation: 43.85s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.97s
# --- Vòng 27/200 ---
#   Performance | Accuracy: 69.14% | Loss: 1.1253
#   Costs       | Computation: 43.80s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.89s
# --- Vòng 28/200 ---
#   Performance | Accuracy: 69.24% | Loss: 1.1240
#   Costs       | Computation: 43.77s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.85s
# --- Vòng 29/200 ---
#   Performance | Accuracy: 69.21% | Loss: 1.1620
#   Costs       | Computation: 43.61s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.70s
# --- Vòng 30/200 ---
#   Performance | Accuracy: 69.17% | Loss: 1.1620
#   Costs       | Computation: 43.92s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.02s
# --- Vòng 31/200 ---
#   Performance | Accuracy: 69.15% | Loss: 1.1822
#   Costs       | Computation: 44.17s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.31s
# --- Vòng 32/200 ---
#   Performance | Accuracy: 69.36% | Loss: 1.1922
#   Costs       | Computation: 43.91s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.01s
# --- Vòng 33/200 ---
#   Performance | Accuracy: 69.21% | Loss: 1.2146
#   Costs       | Computation: 43.83s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.92s
# --- Vòng 34/200 ---
#   Performance | Accuracy: 69.35% | Loss: 1.2162
#   Costs       | Computation: 43.87s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.00s
# --- Vòng 35/200 ---
#   Performance | Accuracy: 69.48% | Loss: 1.2643
#   Costs       | Computation: 43.78s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.88s
# --- Vòng 36/200 ---
#   Performance | Accuracy: 69.65% | Loss: 1.2923
#   Costs       | Computation: 43.63s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.74s
# --- Vòng 37/200 ---
#   Performance | Accuracy: 69.54% | Loss: 1.2971
#   Costs       | Computation: 43.82s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.91s
# --- Vòng 38/200 ---
#   Performance | Accuracy: 69.66% | Loss: 1.3126
#   Costs       | Computation: 43.76s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.86s
# --- Vòng 39/200 ---
#   Performance | Accuracy: 69.81% | Loss: 1.3588
#   Costs       | Computation: 43.99s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.08s
# --- Vòng 40/200 ---
#   Performance | Accuracy: 69.60% | Loss: 1.3682
#   Costs       | Computation: 43.60s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.68s
# --- Vòng 41/200 ---
#   Performance | Accuracy: 69.82% | Loss: 1.3738
#   Costs       | Computation: 43.66s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.75s
# --- Vòng 42/200 ---
#   Performance | Accuracy: 69.91% | Loss: 1.4227
#   Costs       | Computation: 43.63s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.72s
# --- Vòng 43/200 ---
#   Performance | Accuracy: 69.89% | Loss: 1.4428
#   Costs       | Computation: 43.95s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.05s
# --- Vòng 44/200 ---
#   Performance | Accuracy: 70.15% | Loss: 1.4748
#   Costs       | Computation: 43.93s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.02s
# --- Vòng 45/200 ---
#   Performance | Accuracy: 70.13% | Loss: 1.4845
#   Costs       | Computation: 43.75s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.86s
# --- Vòng 46/200 ---
#   Performance | Accuracy: 70.25% | Loss: 1.5179
#   Costs       | Computation: 43.70s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.79s
# --- Vòng 47/200 ---
#   Performance | Accuracy: 70.31% | Loss: 1.5559
#   Costs       | Computation: 43.88s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.98s
# --- Vòng 48/200 ---
#   Performance | Accuracy: 70.15% | Loss: 1.5491
#   Costs       | Computation: 43.61s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.71s
# --- Vòng 49/200 ---
#   Performance | Accuracy: 70.23% | Loss: 1.5656
#   Costs       | Computation: 43.63s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.72s
# --- Vòng 50/200 ---
#   Performance | Accuracy: 70.02% | Loss: 1.5798
#   Costs       | Computation: 44.11s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.22s
# --- Vòng 51/200 ---
#   Performance | Accuracy: 70.15% | Loss: 1.5916
#   Costs       | Computation: 43.77s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.89s
# --- Vòng 52/200 ---
#   Performance | Accuracy: 70.16% | Loss: 1.6463
#   Costs       | Computation: 43.86s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.99s
# --- Vòng 53/200 ---
#   Performance | Accuracy: 70.15% | Loss: 1.6352
#   Costs       | Computation: 43.63s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.73s
# --- Vòng 54/200 ---
#   Performance | Accuracy: 70.20% | Loss: 1.6803
#   Costs       | Computation: 43.69s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.80s
# --- Vòng 55/200 ---
#   Performance | Accuracy: 70.26% | Loss: 1.7135
#   Costs       | Computation: 43.74s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.82s
# --- Vòng 56/200 ---
#   Performance | Accuracy: 70.22% | Loss: 1.7335
#   Costs       | Computation: 44.12s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.22s
# --- Vòng 57/200 ---
#   Performance | Accuracy: 70.28% | Loss: 1.6916
#   Costs       | Computation: 44.04s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.16s
# --- Vòng 58/200 ---
#   Performance | Accuracy: 70.33% | Loss: 1.7122
#   Costs       | Computation: 44.13s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.22s
# --- Vòng 59/200 ---
#   Performance | Accuracy: 70.50% | Loss: 1.7499
#   Costs       | Computation: 43.69s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.78s
# --- Vòng 60/200 ---
#   Performance | Accuracy: 70.27% | Loss: 1.7304
#   Costs       | Computation: 43.56s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.65s
# --- Vòng 61/200 ---
#   Performance | Accuracy: 70.32% | Loss: 1.7333
#   Costs       | Computation: 44.13s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.28s
# --- Vòng 62/200 ---
#   Performance | Accuracy: 70.38% | Loss: 1.7705
#   Costs       | Computation: 43.85s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.00s
# --- Vòng 63/200 ---
#   Performance | Accuracy: 70.33% | Loss: 1.7981
#   Costs       | Computation: 43.60s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.78s
# --- Vòng 64/200 ---
#   Performance | Accuracy: 70.42% | Loss: 1.8123
#   Costs       | Computation: 44.10s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.20s
# --- Vòng 65/200 ---
#   Performance | Accuracy: 70.45% | Loss: 1.8326
#   Costs       | Computation: 43.73s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.82s
# --- Vòng 66/200 ---
#   Performance | Accuracy: 70.37% | Loss: 1.8549
#   Costs       | Computation: 43.86s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.96s
# --- Vòng 67/200 ---
#   Performance | Accuracy: 70.44% | Loss: 1.8736
#   Costs       | Computation: 43.45s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.54s
# --- Vòng 68/200 ---
#   Performance | Accuracy: 70.30% | Loss: 1.8569
#   Costs       | Computation: 43.90s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.99s
# --- Vòng 69/200 ---
#   Performance | Accuracy: 70.38% | Loss: 1.8797
#   Costs       | Computation: 43.83s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.92s
# --- Vòng 70/200 ---
#   Performance | Accuracy: 70.42% | Loss: 1.8993
#   Costs       | Computation: 43.99s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.13s
# --- Vòng 71/200 ---
#   Performance | Accuracy: 70.46% | Loss: 1.9157
#   Costs       | Computation: 43.82s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.92s
# --- Vòng 72/200 ---
#   Performance | Accuracy: 70.42% | Loss: 1.8886
#   Costs       | Computation: 44.05s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.14s
# --- Vòng 73/200 ---
#   Performance | Accuracy: 70.40% | Loss: 1.9106
#   Costs       | Computation: 43.99s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.09s
# --- Vòng 74/200 ---
#   Performance | Accuracy: 70.50% | Loss: 1.8920
#   Costs       | Computation: 43.94s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.11s
# --- Vòng 75/200 ---
#   Performance | Accuracy: 70.43% | Loss: 1.9157
#   Costs       | Computation: 43.77s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.87s
# --- Vòng 76/200 ---
#   Performance | Accuracy: 70.39% | Loss: 1.9359
#   Costs       | Computation: 43.96s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.06s
# --- Vòng 77/200 ---
#   Performance | Accuracy: 70.37% | Loss: 1.9529
#   Costs       | Computation: 43.98s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.10s
# --- Vòng 78/200 ---
#   Performance | Accuracy: 70.52% | Loss: 1.9331
#   Costs       | Computation: 43.84s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.94s
# --- Vòng 79/200 ---
#   Performance | Accuracy: 70.52% | Loss: 1.9287
#   Costs       | Computation: 43.74s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.84s
# --- Vòng 80/200 ---
#   Performance | Accuracy: 70.46% | Loss: 1.9265
#   Costs       | Computation: 43.50s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.59s
# --- Vòng 81/200 ---
#   Performance | Accuracy: 70.43% | Loss: 1.9471
#   Costs       | Computation: 43.92s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.02s
# --- Vòng 82/200 ---
#   Performance | Accuracy: 70.46% | Loss: 1.9661
#   Costs       | Computation: 43.98s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.08s
# --- Vòng 83/200 ---
#   Performance | Accuracy: 70.47% | Loss: 1.9832
#   Costs       | Computation: 43.93s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.02s
# --- Vòng 84/200 ---
#   Performance | Accuracy: 70.49% | Loss: 1.9987
#   Costs       | Computation: 44.21s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.30s
# --- Vòng 85/200 ---
#   Performance | Accuracy: 70.42% | Loss: 1.9977
#   Costs       | Computation: 43.31s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.41s
# --- Vòng 86/200 ---
#   Performance | Accuracy: 70.48% | Loss: 2.0126
#   Costs       | Computation: 43.56s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.65s
# --- Vòng 87/200 ---
#   Performance | Accuracy: 70.52% | Loss: 2.0258
#   Costs       | Computation: 43.63s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.73s
# --- Vòng 88/200 ---
#   Performance | Accuracy: 70.51% | Loss: 2.0379
#   Costs       | Computation: 43.70s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.87s
# --- Vòng 89/200 ---
#   Performance | Accuracy: 70.54% | Loss: 2.0095
#   Costs       | Computation: 43.68s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.78s
# --- Vòng 90/200 ---
#   Performance | Accuracy: 70.54% | Loss: 2.0264
#   Costs       | Computation: 44.03s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.14s
# --- Vòng 91/200 ---
#   Performance | Accuracy: 70.63% | Loss: 2.0410
#   Costs       | Computation: 44.11s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.21s
# --- Vòng 92/200 ---
#   Performance | Accuracy: 70.68% | Loss: 2.0539
#   Costs       | Computation: 44.12s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.28s
# --- Vòng 93/200 ---
#   Performance | Accuracy: 70.69% | Loss: 2.0658
#   Costs       | Computation: 43.44s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.59s
# --- Vòng 94/200 ---
#   Performance | Accuracy: 70.70% | Loss: 2.0771
#   Costs       | Computation: 43.58s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.68s
# --- Vòng 95/200 ---
#   Performance | Accuracy: 70.72% | Loss: 2.0872
#   Costs       | Computation: 43.63s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.73s
# --- Vòng 96/200 ---
#   Performance | Accuracy: 70.73% | Loss: 2.0963
#   Costs       | Computation: 43.99s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.09s
# --- Vòng 97/200 ---
#   Performance | Accuracy: 70.54% | Loss: 2.0709
#   Costs       | Computation: 44.05s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.14s
# --- Vòng 98/200 ---
#   Performance | Accuracy: 70.65% | Loss: 2.0850
#   Costs       | Computation: 44.20s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.29s
# --- Vòng 99/200 ---
#   Performance | Accuracy: 70.65% | Loss: 2.0977
#   Costs       | Computation: 43.94s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.03s
# --- Vòng 100/200 ---
#   Performance | Accuracy: 70.64% | Loss: 2.1086
#   Costs       | Computation: 43.84s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.98s
# --- Vòng 101/200 ---
#   Performance | Accuracy: 70.66% | Loss: 2.1188
#   Costs       | Computation: 43.84s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.96s
# --- Vòng 102/200 ---
#   Performance | Accuracy: 70.65% | Loss: 2.1282
#   Costs       | Computation: 43.70s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.81s
# --- Vòng 103/200 ---
#   Performance | Accuracy: 70.57% | Loss: 2.1105
#   Costs       | Computation: 43.89s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.98s
# --- Vòng 104/200 ---
#   Performance | Accuracy: 70.56% | Loss: 2.1214
#   Costs       | Computation: 43.83s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.94s
# --- Vòng 105/200 ---
#   Performance | Accuracy: 70.64% | Loss: 2.0879
#   Costs       | Computation: 43.64s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.73s
# --- Vòng 106/200 ---
#   Performance | Accuracy: 70.71% | Loss: 2.1020
#   Costs       | Computation: 43.37s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.48s
# --- Vòng 107/200 ---
#   Performance | Accuracy: 70.70% | Loss: 2.1154
#   Costs       | Computation: 43.78s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.88s
# --- Vòng 108/200 ---
#   Performance | Accuracy: 70.68% | Loss: 2.1274
#   Costs       | Computation: 44.03s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.12s
# --- Vòng 109/200 ---
#   Performance | Accuracy: 70.74% | Loss: 2.1380
#   Costs       | Computation: 43.64s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.73s
# --- Vòng 110/200 ---
#   Performance | Accuracy: 70.74% | Loss: 2.1477
#   Costs       | Computation: 43.89s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.98s
# --- Vòng 111/200 ---
#   Performance | Accuracy: 70.77% | Loss: 2.1568
#   Costs       | Computation: 44.01s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.11s
# --- Vòng 112/200 ---
#   Performance | Accuracy: 70.79% | Loss: 2.1656
#   Costs       | Computation: 43.83s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.92s
# --- Vòng 113/200 ---
#   Performance | Accuracy: 70.83% | Loss: 2.1738
#   Costs       | Computation: 43.74s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.83s
# --- Vòng 114/200 ---
#   Performance | Accuracy: 70.81% | Loss: 2.1817
#   Costs       | Computation: 43.78s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.88s
# --- Vòng 115/200 ---
#   Performance | Accuracy: 70.81% | Loss: 2.1892
#   Costs       | Computation: 43.83s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.93s
# --- Vòng 116/200 ---
#   Performance | Accuracy: 70.81% | Loss: 2.1962
#   Costs       | Computation: 43.79s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.91s
# --- Vòng 117/200 ---
#   Performance | Accuracy: 70.82% | Loss: 2.2033
#   Costs       | Computation: 44.05s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.14s
# --- Vòng 118/200 ---
#   Performance | Accuracy: 70.81% | Loss: 2.2101
#   Costs       | Computation: 44.09s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.18s
# --- Vòng 119/200 ---
#   Performance | Accuracy: 70.83% | Loss: 2.2166
#   Costs       | Computation: 43.72s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.81s
# --- Vòng 120/200 ---
#   Performance | Accuracy: 70.85% | Loss: 2.2227
#   Costs       | Computation: 43.82s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.91s
# --- Vòng 121/200 ---
#   Performance | Accuracy: 70.85% | Loss: 2.2286
#   Costs       | Computation: 43.93s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.02s
# --- Vòng 122/200 ---
#   Performance | Accuracy: 70.87% | Loss: 2.2348
#   Costs       | Computation: 43.66s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.82s
# --- Vòng 123/200 ---
#   Performance | Accuracy: 70.86% | Loss: 2.2407
#   Costs       | Computation: 43.94s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.06s
# --- Vòng 124/200 ---
#   Performance | Accuracy: 70.88% | Loss: 2.2464
#   Costs       | Computation: 43.61s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.71s
# --- Vòng 125/200 ---
#   Performance | Accuracy: 70.87% | Loss: 2.2517
#   Costs       | Computation: 43.59s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.68s
# --- Vòng 126/200 ---
#   Performance | Accuracy: 70.87% | Loss: 2.2571
#   Costs       | Computation: 43.86s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.00s
# --- Vòng 127/200 ---
#   Performance | Accuracy: 70.87% | Loss: 2.2624
#   Costs       | Computation: 43.73s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.82s
# --- Vòng 128/200 ---
#   Performance | Accuracy: 70.83% | Loss: 2.2676
#   Costs       | Computation: 43.35s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.46s
# --- Vòng 129/200 ---
#   Performance | Accuracy: 70.83% | Loss: 2.2724
#   Costs       | Computation: 43.67s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.83s
# --- Vòng 130/200 ---
#   Performance | Accuracy: 70.84% | Loss: 2.2773
#   Costs       | Computation: 43.87s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.97s
# --- Vòng 131/200 ---
#   Performance | Accuracy: 70.82% | Loss: 2.2821
#   Costs       | Computation: 43.81s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.90s
# --- Vòng 132/200 ---
#   Performance | Accuracy: 70.84% | Loss: 2.2867
#   Costs       | Computation: 43.44s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.53s
# --- Vòng 133/200 ---
#   Performance | Accuracy: 70.85% | Loss: 2.2916
#   Costs       | Computation: 43.52s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.62s
# --- Vòng 134/200 ---
#   Performance | Accuracy: 70.84% | Loss: 2.2961
#   Costs       | Computation: 43.86s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.97s
# --- Vòng 135/200 ---
#   Performance | Accuracy: 70.85% | Loss: 2.3003
#   Costs       | Computation: 44.07s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.16s
# --- Vòng 136/200 ---
#   Performance | Accuracy: 70.83% | Loss: 2.3049
#   Costs       | Computation: 43.87s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.96s
# --- Vòng 137/200 ---
#   Performance | Accuracy: 70.83% | Loss: 2.3093
#   Costs       | Computation: 43.96s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.08s
# --- Vòng 138/200 ---
#   Performance | Accuracy: 70.82% | Loss: 2.3137
#   Costs       | Computation: 43.93s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.06s
# --- Vòng 139/200 ---
#   Performance | Accuracy: 70.82% | Loss: 2.3180
#   Costs       | Computation: 43.95s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.04s
# --- Vòng 140/200 ---
#   Performance | Accuracy: 70.82% | Loss: 2.3221
#   Costs       | Computation: 43.94s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.04s
# --- Vòng 141/200 ---
#   Performance | Accuracy: 70.82% | Loss: 2.3262
#   Costs       | Computation: 43.90s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.00s
# --- Vòng 142/200 ---
#   Performance | Accuracy: 70.81% | Loss: 2.3301
#   Costs       | Computation: 43.78s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.88s
# --- Vòng 143/200 ---
#   Performance | Accuracy: 70.82% | Loss: 2.3341
#   Costs       | Computation: 43.88s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.97s
# --- Vòng 144/200 ---
#   Performance | Accuracy: 70.77% | Loss: 2.3382
#   Costs       | Computation: 43.55s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.66s
# --- Vòng 145/200 ---
#   Performance | Accuracy: 70.78% | Loss: 2.3419
#   Costs       | Computation: 43.97s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.13s
# --- Vòng 146/200 ---
#   Performance | Accuracy: 70.78% | Loss: 2.3457
#   Costs       | Computation: 43.73s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.89s
# --- Vòng 147/200 ---
#   Performance | Accuracy: 70.79% | Loss: 2.3494
#   Costs       | Computation: 43.57s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.67s
# --- Vòng 148/200 ---
#   Performance | Accuracy: 70.78% | Loss: 2.3532
#   Costs       | Computation: 43.79s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.88s
# --- Vòng 149/200 ---
#   Performance | Accuracy: 70.76% | Loss: 2.3568
#   Costs       | Computation: 43.63s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.77s
# --- Vòng 150/200 ---
#   Performance | Accuracy: 70.77% | Loss: 2.3605
#   Costs       | Computation: 44.10s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.23s
# --- Vòng 151/200 ---
#   Performance | Accuracy: 70.79% | Loss: 2.3639
#   Costs       | Computation: 44.12s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.25s
# --- Vòng 152/200 ---
#   Performance | Accuracy: 70.79% | Loss: 2.3672
#   Costs       | Computation: 43.85s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.94s
# --- Vòng 153/200 ---
#   Performance | Accuracy: 70.77% | Loss: 2.3708
#   Costs       | Computation: 43.64s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.81s
# --- Vòng 154/200 ---
#   Performance | Accuracy: 70.80% | Loss: 2.3741
#   Costs       | Computation: 43.97s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.07s
# --- Vòng 155/200 ---
#   Performance | Accuracy: 70.80% | Loss: 2.3775
#   Costs       | Computation: 43.68s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.77s
# --- Vòng 156/200 ---
#   Performance | Accuracy: 70.81% | Loss: 2.3807
#   Costs       | Computation: 44.02s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.12s
# --- Vòng 157/200 ---
#   Performance | Accuracy: 70.81% | Loss: 2.3839
#   Costs       | Computation: 43.92s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.02s
# --- Vòng 158/200 ---
#   Performance | Accuracy: 70.80% | Loss: 2.3872
#   Costs       | Computation: 44.27s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.39s
# --- Vòng 159/200 ---
#   Performance | Accuracy: 70.81% | Loss: 2.3904
#   Costs       | Computation: 43.83s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.92s
# --- Vòng 160/200 ---
#   Performance | Accuracy: 70.83% | Loss: 2.3935
#   Costs       | Computation: 43.86s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.95s
# --- Vòng 161/200 ---
#   Performance | Accuracy: 70.83% | Loss: 2.3968
#   Costs       | Computation: 44.14s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.28s
# --- Vòng 162/200 ---
#   Performance | Accuracy: 70.82% | Loss: 2.3998
#   Costs       | Computation: 43.65s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.76s
# --- Vòng 163/200 ---
#   Performance | Accuracy: 70.82% | Loss: 2.4027
#   Costs       | Computation: 44.11s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.26s
# --- Vòng 164/200 ---
#   Performance | Accuracy: 70.83% | Loss: 2.4058
#   Costs       | Computation: 43.99s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.09s
# --- Vòng 165/200 ---
#   Performance | Accuracy: 70.83% | Loss: 2.4089
#   Costs       | Computation: 43.96s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.12s
# --- Vòng 166/200 ---
#   Performance | Accuracy: 70.82% | Loss: 2.4116
#   Costs       | Computation: 43.65s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.76s
# --- Vòng 167/200 ---
#   Performance | Accuracy: 70.83% | Loss: 2.4146
#   Costs       | Computation: 43.66s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.76s
# --- Vòng 168/200 ---
#   Performance | Accuracy: 70.82% | Loss: 2.4175
#   Costs       | Computation: 43.86s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.96s
# --- Vòng 169/200 ---
#   Performance | Accuracy: 70.79% | Loss: 2.4202
#   Costs       | Computation: 43.87s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.01s
# --- Vòng 170/200 ---
#   Performance | Accuracy: 70.81% | Loss: 2.4232
#   Costs       | Computation: 43.90s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.02s
# --- Vòng 171/200 ---
#   Performance | Accuracy: 70.79% | Loss: 2.4258
#   Costs       | Computation: 43.87s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.97s
# --- Vòng 172/200 ---
#   Performance | Accuracy: 70.79% | Loss: 2.4285
#   Costs       | Computation: 44.09s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.22s
# --- Vòng 173/200 ---
#   Performance | Accuracy: 70.84% | Loss: 2.3760
#   Costs       | Computation: 43.88s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.98s
# --- Vòng 174/200 ---
#   Performance | Accuracy: 70.87% | Loss: 2.3808
#   Costs       | Computation: 44.20s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.34s
# --- Vòng 175/200 ---
#   Performance | Accuracy: 70.87% | Loss: 2.3860
#   Costs       | Computation: 43.80s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.96s
# --- Vòng 176/200 ---
#   Performance | Accuracy: 70.88% | Loss: 2.3913
#   Costs       | Computation: 43.88s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.98s
# --- Vòng 177/200 ---
#   Performance | Accuracy: 70.89% | Loss: 2.3962
#   Costs       | Computation: 43.97s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.07s
# --- Vòng 178/200 ---
#   Performance | Accuracy: 70.88% | Loss: 2.4009
#   Costs       | Computation: 43.99s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.12s
# --- Vòng 179/200 ---
#   Performance | Accuracy: 70.88% | Loss: 2.4053
#   Costs       | Computation: 44.19s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.36s
# --- Vòng 180/200 ---
#   Performance | Accuracy: 70.84% | Loss: 2.4095
#   Costs       | Computation: 43.90s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.00s
# --- Vòng 181/200 ---
#   Performance | Accuracy: 70.82% | Loss: 2.4135
#   Costs       | Computation: 43.90s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.99s
# --- Vòng 182/200 ---
#   Performance | Accuracy: 70.84% | Loss: 2.4174
#   Costs       | Computation: 43.93s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.03s
# --- Vòng 183/200 ---
#   Performance | Accuracy: 70.83% | Loss: 2.4212
#   Costs       | Computation: 43.62s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.78s
# --- Vòng 184/200 ---
#   Performance | Accuracy: 70.83% | Loss: 2.4248
#   Costs       | Computation: 43.91s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.01s
# --- Vòng 185/200 ---
#   Performance | Accuracy: 70.83% | Loss: 2.4283
#   Costs       | Computation: 44.14s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.27s
# --- Vòng 186/200 ---
#   Performance | Accuracy: 70.81% | Loss: 2.4318
#   Costs       | Computation: 43.91s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.01s
# --- Vòng 187/200 ---
#   Performance | Accuracy: 70.80% | Loss: 2.4352
#   Costs       | Computation: 43.66s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.76s
# --- Vòng 188/200 ---
#   Performance | Accuracy: 70.80% | Loss: 2.4384
#   Costs       | Computation: 43.64s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.74s
# --- Vòng 189/200 ---
#   Performance | Accuracy: 70.79% | Loss: 2.4417
#   Costs       | Computation: 43.82s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.94s
# --- Vòng 190/200 ---
#   Performance | Accuracy: 70.78% | Loss: 2.4447
#   Costs       | Computation: 43.89s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.00s
# --- Vòng 191/200 ---
#   Performance | Accuracy: 70.77% | Loss: 2.4478
#   Costs       | Computation: 43.93s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.02s
# --- Vòng 192/200 ---
#   Performance | Accuracy: 70.78% | Loss: 2.4508
#   Costs       | Computation: 43.98s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.07s
# --- Vòng 193/200 ---
#   Performance | Accuracy: 70.79% | Loss: 2.4538
#   Costs       | Computation: 43.94s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.04s
# --- Vòng 194/200 ---
#   Performance | Accuracy: 70.80% | Loss: 2.4567
#   Costs       | Computation: 44.02s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.16s
# --- Vòng 195/200 ---
#   Performance | Accuracy: 70.80% | Loss: 2.4596
#   Costs       | Computation: 44.12s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.21s
# --- Vòng 196/200 ---
#   Performance | Accuracy: 70.79% | Loss: 2.4623
#   Costs       | Computation: 43.81s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.91s
# --- Vòng 197/200 ---
#   Performance | Accuracy: 70.77% | Loss: 2.4652
#   Costs       | Computation: 43.61s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.70s
# --- Vòng 198/200 ---
#   Performance | Accuracy: 70.76% | Loss: 2.4677
#   Costs       | Computation: 44.03s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.12s
# --- Vòng 199/200 ---
#   Performance | Accuracy: 70.76% | Loss: 2.4705
#   Costs       | Computation: 43.41s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 44.51s
# --- Vòng 200/200 ---
#   Performance | Accuracy: 70.76% | Loss: 2.4731
#   Costs       | Computation: 43.94s | Communication: 809.55MB
#   Resources   | Peak RAM Usage (Client): 0.00MB | Peak GPU Mem (Client): 0.00MB
#   Round Time  | Total elapsed: 45.05s
#
# --- MÔ PHỎNG HOÀN TẤT ---

# %%
# Cell 6: Trực quan hóa kết quả 📊
fig, axes = plt.subplots(2, 2, figsize=(16, 12))
title = (f"Algorithm: {config.ALGORITHM.upper()} | Dataset: {data_params['dataset_name']} "
         f"({data_params['distribution_mode']}) | Clients: {num_clients}")
fig.suptitle(title, fontsize=18)
rounds = history['rounds']
axes[0, 0].plot(rounds, history['accuracy'], marker='o'); axes[0, 0].set_title("Độ chính xác"); axes[0, 0].grid(True); axes[0, 0].set_ylim(bottom=0)
axes[0, 1].plot(rounds, history['loss'], marker='x', color='r'); axes[0, 1].set_title("Hàm mất mát"); axes[0, 1].grid(True)
axes[1, 0].plot(rounds, np.cumsum(history['comp_cost']), marker='s', color='g'); axes[1, 0].set_title("Chi phí tính toán tích lũy"); axes[1, 0].grid(True)
axes[1, 1].plot(rounds, np.cumsum(history['comm_cost']), marker='d', color='purple'); axes[1, 1].set_title("Chi phí giao tiếp tích lũy"); axes[1, 1].grid(True)
for ax in axes.flat: ax.set_xlabel("Vòng giao tiếp")
plt.tight_layout(rect=[0, 0, 1, 0.95]); plt.show()
